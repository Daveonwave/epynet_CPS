# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
# font-size: 14px;
# </style>

# %%
import pandas as pd

# %%
csv_file = "links-2022_08_11-08_54_PM.csv"

to_load = 'to_load/'
filename = to_load + csv_file

# %%
df_links = pd.read_csv(filename, header=[0, 1, 2])
df_links
# Out:
#                  link       pumps                                             \
#                    id         P78                            P79
#            properties        flow      energy status        flow      energy
# 0     0 days 00:00:00  526.499820  168.083354    1.0  526.499820  168.083354
# 1     0 days 00:05:00  531.174045  169.442556    1.0  531.174045  169.442556
# 2     0 days 00:10:00  535.793489  170.783528    1.0  535.793489  170.783528
# 3     0 days 00:15:00  540.363539  172.107912    1.0  540.363539  172.107912
# 4     0 days 00:19:00  543.983405  173.155347    1.0  543.983405  173.155347
# ...               ...         ...         ...    ...         ...         ...
# 2014  6 days 23:40:00  737.196008  227.025201    1.0  737.196008  227.025201
# 2015  6 days 23:45:00  737.196008  227.025202    1.0  737.196008  227.025202
# 2016  6 days 23:50:00  737.196008  227.025201    1.0  737.196008  227.025201
# ...
