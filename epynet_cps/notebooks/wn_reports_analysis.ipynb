# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
# font-size: 14px;
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
# font-size: 14px;
# </style>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

to_load = 'to_load/'

# %%
def plot_report_data(filename, entity_type, uids, prop):
    """
    Plot data retrieve from links or nodes csv report.
    :param filename: name of the csv report file
    :param entity_type: kind of links or nodes to plot
    :param uids: ids of the entities to plot
    :param prop: variable to plot
    """
    df = pd.read_csv(filename, header=[0, 1, 2])
    
    fig, axs = plt.subplots(1, 1, figsize=(15,7), sharex=True)
    for uid in uids:
        axs.plot(df[entity_type][uid][prop], label=uid)
    axs.set_title(entity_type + ': ' + prop)
    axs.legend()

# %%
csv_file = "weighted_consecutive_updates_penalty_v4_1/PLC2_ground-1.csv"
filename = to_load + csv_file

entity_type = 'pumps'
uids = ['P78', 'P79']
prop = 'energy'
plot_report_data(filename=filename, entity_type=entity_type, uids=uids, prop=prop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pumps'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
csv_file = "weighted_consecutive_updates_penalty/links0.csv"
filename = to_load + csv_file

entity_type = 'pumps'
uids = ['P78', 'P79']
prop = 'flow'
plot_report_data(filename=filename, entity_type=entity_type, uids=uids, prop=prop)

# %%
csv_file = "weighted_consecutive_updates_penalty/links0.csv"
filename = to_load + csv_file

entity_type = 'pumps'
uids = ['P78', 'P79']
prop = 'status'
plot_report_data(filename=filename, entity_type=entity_type, uids=uids, prop=prop)

# %%
df = pd.read_csv(filename, header=[0, 1, 2])
df.xs('status', level=2, axis=1, drop_level=False).head(50)
# Out:
#     pumps
#       P78    P79
#    status status
# 0     0.0    0.0
# 1     1.0    1.0
# 2     1.0    1.0
# 3     1.0    1.0
# 4     1.0    1.0
# 5     1.0    1.0
# 6     1.0    1.0
# 7     1.0    1.0
# 8     1.0    1.0
# 9     1.0    1.0
# 10    1.0    1.0
# 11    1.0    1.0
# 12    1.0    1.0
# 13    1.0    1.0
# 14    1.0    1.0
# 15    1.0    1.0
# 16    1.0    1.0
# 17    1.0    1.0
# 18    1.0    1.0
# 19    1.0    1.0
# 20    0.0    1.0
# 21    0.0    1.0
# 22    0.0    0.0
# 23    0.0    0.0
# 24    0.0    0.0
# 25    0.0    0.0
# 26    0.0    0.0
# 27    0.0    0.0
# 28    0.0    0.0
# 29    0.0    0.0
# 30    0.0    0.0
# 31    0.0    0.0
# 32    0.0    0.0
# 33    0.0    0.0
# 34    0.0    0.0
# 35    0.0    0.0
# 36    0.0    0.0
# 37    0.0    0.0
# 38    0.0    0.0
# 39    0.0    0.0
# 40    0.0    0.0
# 41    0.0    0.0
# 42    0.0    0.0
# 43    0.0    0.0
# 44    0.0    0.0
# 45    0.0    0.0
# 46    0.0    0.0
# 47    0.0    0.0
# 48    0.0    0.0
# 49    0.0    1.0
